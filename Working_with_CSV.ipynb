# %% [markdown]
# <a href="https://colab.research.google.com/github/rajarshicode14/sorting-algorithms/blob/main/Working_with_CSV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Opening a local csv file

# %%
df = pd.read_csv('/content/aug_train.csv')
df.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM        >20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# ...

# %% [markdown]
# ### Opening a csv file from URL

# %%
import requests
from io import StringIO

url = "https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}
req = requests.get(url, headers=headers)
data = StringIO(req.text)

pd.read_csv(data)
# Out:
#        Country         Region
# 0      Algeria         AFRICA
# 1       Angola         AFRICA
# 2        Benin         AFRICA
# 3     Botswana         AFRICA
# 4      Burkina         AFRICA
# ..         ...            ...
# 189   Paraguay  SOUTH AMERICA
# 190       Peru  SOUTH AMERICA
# 191   Suriname  SOUTH AMERICA
# 192    Uruguay  SOUTH AMERICA
# 193  Venezuela  SOUTH AMERICA
#
# [194 rows x 2 columns]

# %% [markdown]
# ### Sep parameter for reading tsv file

# %%
df = pd.read_csv('/content/movie_titles_metadata.tsv', sep = '\t', names = ['S.No', 'Name', 'Year', 'Ratings', 'Votes', 'Genres']) ## Use name parameter to give custom headings when there is no headings in the original data

# %%
df
# Out:
#      S.No                        Name  Year  Ratings     Votes  \
# 0      m0  10 things i hate about you  1999      6.9   62847.0
# 1      m1  1492: conquest of paradise  1992      6.2   10421.0
# 2      m2                  15 minutes  2001      6.1   25854.0
# 3      m3       2001: a space odyssey  1968      8.4  163227.0
# 4      m4                     48 hrs.  1982      6.9   22289.0
# ..    ...                         ...   ...      ...       ...
# 612  m612                    watchmen  2009      7.8  135229.0
# 613  m613                         xxx  2002      5.6   53505.0
# 614  m614                       x-men  2000      7.4  122149.0
# 615  m615          young frankenstein  1974      8.0   57618.0
# 616  m616                   zulu dawn  1979      6.4    1911.0
#
#                                                 Genres
# 0                                 ['comedy' 'romance']
# 1          ['adventure' 'biography' 'drama' 'history']
# ...

# %% [markdown]
# ### Index_col parameter

# %%
pd.read_csv('/content/aug_train.csv', index_col = 'enrollee_id') # Sets index to a particular column replacing the dafault one
# Out:
#                  city  city_development_index gender      relevent_experience  \
# enrollee_id
# 8949         city_103                   0.920   Male  Has relevent experience
# 29725         city_40                   0.776   Male   No relevent experience
# 11561         city_21                   0.624    NaN   No relevent experience
# 33241        city_115                   0.789    NaN   No relevent experience
# 666          city_162                   0.767   Male  Has relevent experience
# ...               ...                     ...    ...                      ...
# 7386         city_173                   0.878   Male   No relevent experience
# 31398        city_103                   0.920   Male  Has relevent experience
# 24576        city_103                   0.920   Male  Has relevent experience
# 5756          city_65                   0.802   Male  Has relevent experience
# 23834         city_67                   0.855    NaN   No relevent experience
#
# ...

# %% [markdown]
# ### Header parameter (To make a particular row as a header)

# %%
pd.read_csv('/content/test.csv', header = 1)
# Out:
#    0  enrollee_id      city  city_development_index gender  \
# 0  1        29725   city_40                   0.776   Male
# 1  2        11561   city_21                   0.624    NaN
# 2  3        33241  city_115                   0.789    NaN
# 3  4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0   No relevent experience       no_enrollment        Graduate
# 1   No relevent experience    Full time course        Graduate
# 2   No relevent experience                 NaN        Graduate
# 3  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM         15        50-99         Pvt Ltd           >4
# 1             STEM          5          NaN             NaN        never
# 2  Business Degree         <1          NaN         Pvt Ltd        never
# ...

# %% [markdown]
# ### Use_cols parameter( To use only selected columns from the dataset)

# %%
pd.read_csv('/content/aug_train.csv', usecols = ['enrollee_id', 'gender', 'education_level'])
# Out:
#        enrollee_id gender education_level
# 0             8949   Male        Graduate
# 1            29725   Male        Graduate
# 2            11561    NaN        Graduate
# 3            33241    NaN        Graduate
# 4              666   Male         Masters
# ...            ...    ...             ...
# 19153         7386   Male        Graduate
# 19154        31398   Male        Graduate
# 19155        24576   Male        Graduate
# 19156         5756   Male     High School
# 19157        23834    NaN  Primary School
#
# [19158 rows x 3 columns]

# %% [markdown]
# ### Squeeze parameter (To convert a pandas dataframe into a series)

# %%
pd.read_csv('/content/aug_train.csv', usecols = ['education_level'], squeeze = True)
# Out:
# <ipython-input-18-92ce86e52ba9>:1: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   pd.read_csv('/content/aug_train.csv', usecols = ['education_level'], squeeze = True)
# 0              Graduate
# 1              Graduate
# 2              Graduate
# 3              Graduate
# 4               Masters
#               ...
# 19153          Graduate
# 19154          Graduate
# 19155          Graduate
# 19156       High School
# 19157    Primary School
# Name: education_level, Length: 19158, dtype: object

# %% [markdown]
# ### Skiprows/nrows parameter (skiprows for excluding rows based on given indexes, nrows imports ony those number of rows which are mentioned)

# %%
pd.read_csv('/content/aug_train.csv')
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
pd.read_csv('/content/aug_train.csv',skiprows = [1, 3]) # it follows 1 indexing
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0            29725   city_40                   0.776   Male
# 1            33241  city_115                   0.789    NaN
# 2              666  city_162                   0.767   Male
# 3            21651  city_176                   0.764    NaN
# 4            28806  city_160                   0.920   Male
# ...            ...       ...                     ...    ...
# 19151         7386  city_173                   0.878   Male
# 19152        31398  city_103                   0.920   Male
# 19153        24576  city_103                   0.920   Male
# 19154         5756   city_65                   0.802   Male
# 19155        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0       No relevent experience       no_enrollment        Graduate
# 1       No relevent experience                 NaN        Graduate
# ...

# %%
pd.read_csv('/content/aug_train.csv', nrows = 50)
# Out:
#     enrollee_id      city  city_development_index  gender  \
# 0          8949  city_103                   0.920    Male
# 1         29725   city_40                   0.776    Male
# 2         11561   city_21                   0.624     NaN
# 3         33241  city_115                   0.789     NaN
# 4           666  city_162                   0.767    Male
# 5         21651  city_176                   0.764     NaN
# 6         28806  city_160                   0.920    Male
# 7           402   city_46                   0.762    Male
# 8         27107  city_103                   0.920    Male
# 9           699  city_103                   0.920     NaN
# 10        29452   city_21                   0.624     NaN
# 11        23853  city_103                   0.920    Male
# 12        25619   city_61                   0.913    Male
# 13         5826   city_21                   0.624    Male
# 14         8722   city_21                   0.624     NaN
# ...

# %% [markdown]
# ### Encoding parameter (It is used when the dataset is not in UTF-8 encoding)

# %%
# ex: pd.read_csv('test.csv', encoding = 'latin-1')
# the dataset is not in UTF-8 encoding rather in latin-1, hence we used latin-1

# %% [markdown]
# ### skip bad lines( it is used when there are more number of columns in some rows than other rows. It removes those rows)

# %%
# ex: pd.read_csv('test.csv', error_bad_lines = False)

# %% [markdown]
# ### dtype parameter (It is used to change the datatype of any column. The conversion must be compatible)

# %%
pd.read_csv('/content/aug_train.csv', dtype = {'target': int}) # previously target was float64
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %% [markdown]
# ### parse_dates

# %% [markdown]
# ### converters (Sometimes we need to use convert the data point to a short hand, ex: India to IND then we use converter parameters. It takes a dict and uses a function to convert the data)

# %%
# converter function

def rename(name):
    if name == 'Royal Challengers Bangalore':
        return 'RCB'
    else:
        return name

# %%
pd.read_csv('/content/IPL Matches 2008-2020.csv', converters = {'team1': rename}) # changed Royal Challengers Bangalore to RCB
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %% [markdown]
# ### Loading huge dataset in chunks

# %%
dfs = pd.read_csv('/content/aug_train.csv', chunksize = 400)

# %%
# now each chunks are stored in dfs, So we must use loops to operate on each individual dataframe

for chunks in dfs:
    print(chunks.shape)
# Out:
# (400, 14)
# (400, 14)
# (400, 14)
# (400, 14)
# (400, 14)
# (400, 14)
# (400, 14)
# (400, 14)
# (400, 14)
# (400, 14)
# (400, 14)
# (400, 14)
# (400, 14)
# (400, 14)
# (400, 14)
# (400, 14)
# (400, 14)
# (400, 14)
# (400, 14)
# (400, 14)
# (400, 14)
# (400, 14)
# (400, 14)
# (400, 14)
# (400, 14)
# (400, 14)
# (400, 14)
# (400, 14)
# (400, 14)
# (400, 14)
# (400, 14)
# (400, 14)
# (400, 14)
# (400, 14)
# (400, 14)
# (400, 14)
# (400, 14)
# (400, 14)
# (400, 14)
# (400, 14)
# (400, 14)
# (400, 14)
# (400, 14)
# (400, 14)
# (400, 14)
# (400, 14)
# (400, 14)
# (358, 14)
